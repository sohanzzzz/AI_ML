# %%
import pandas as pd
import matplotlib

# %%
info={
    "Name": ["Sohan","Rahul","Shraddha"],
    "CGPA": [7.3,6.8,9.5]
    }
df=pd.DataFrame(info)
print(df)
# Out:
#        Name  CGPA
# 0     Sohan   7.3
# 1     Rahul   6.8
# 2  Shraddha   9.5

# %%
df
# Out:
#        Name  CGPA
# 0     Sohan   7.3
# 1     Rahul   6.8
# 2  Shraddha   9.5

# %%
s=pd.Series([1,2,3,4])
print(s,type(s))
print(s[0]) #prints 1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64 <class 'pandas.core.series.Series'>
# 1

# %%
s=pd.Series([56,67,45,43,23], index=["Ram","Shyam","Adam","Eve","Sohan"])
print(s)
print(s["Sohan"]) #prints labelled index "Sohan" value
print(s.index)
# Out:
# Ram      56
# Shyam    67
# Adam     45
# Eve      43
# Sohan    23
# dtype: int64
# 23
# Index(['Ram', 'Shyam', 'Adam', 'Eve', 'Sohan'], dtype='object')

# %%
import numpy as np
Info={
    "Name": ["Sohan","Rahul","Shraddha"],
    "CGPA": [7.3,6.8,9.5],
    "Age": [21,21,25]
    }
df=pd.DataFrame(info)
print(df)
df1=pd.DataFrame([["Adam",21],["Bob",22],["Jack",34]],columns=["Name","Age"])
print(df1)
np_arr=np.array([[1,2,3],[4,5,6]])
df2=pd.DataFrame(np_arr,columns=["A","B","C"], index=["i.","ii."])
print(df2)
# Out:
#        Name  CGPA
# 0     Sohan   7.3
# 1     Rahul   6.8
# 2  Shraddha   9.5
#    Name  Age
# 0  Adam   21
# 1   Bob   22
# 2  Jack   34
#      A  B  C
# i.   1  2  3
# ii.  4  5  6

# %%
df=pd.read_csv("employee_data.csv")
print(df)
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
df=pd.read_csv("globalAirQuality.csv")
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
#columns
df[["city","aqi"]]
#rows
df.loc[0:2]    #end idx included 
df.loc[2] 

df.iloc[0:3]   #end idx not included
df.iloc[2]
#cells-row x column
df.loc[0:2,["city","aqi"]]
df.columns
df.iloc[0:3,[2,11]]

#select single scalar values 
df.at[2,"city"]
df.iat[0,2]
# Out:
# 'New York'

# %%
#Filtering Data
df[df["aqi"]>100]
df[df["aqi"]>100][["city","aqi"]] #Chaining

df[(df["aqi"]>100) & (df["temperature"]>30)] #Using and op
aqi_data=df[(df["aqi"]>100) & (df["temperature"]>30)][["city","aqi"]]
aqi_data
aqi_data.loc[6] #label starts from 6  in aqi_data
aqi_data.iloc[0] #index always starts from 0

#Query method
aqi_value=100
df.query("aqi > 100")
df.query("aqi > 100 & temperature > 30")[["city","aqi"]] #and operator and chained comaprisons
df.query("aqi > @aqi_value & temperature > 30")[["city","aqi"]] #using python reference variables
# Out:
#            city  aqi
# 6      New York  155
# 7      New York  115
# 14     New York  121
# 17     New York  127
# 25     New York  113
# ...         ...  ...
# 17947    Zurich  107
# 17950    Zurich  140
# 17975    Zurich  111
# 17976    Zurich  146
# 17991    Zurich  104
#
# [2384 rows x 2 columns]

# %%
#Cleaning the data
df=pd.read_csv("raw_data.csv")
df.isnull()
df.isnull().sum()  #gives the sum of the missing values in the columns 
df.dropna() #removes the rows that have a null value
df.dropna(axis=1) #removes the columns that have a null value
mean_age=df["age"].mean()
df["age"].fillna(mean_age) #fills the Nan values with the mean of the ages
cleaned_data=df.copy()
cleaned_data["age"]=cleaned_data["age"].fillna(mean_age)
cleaned_data
df.ffill()
df.bfill()
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  34.0  Canada   Female  62000.0
# 3    3          Alex  34.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female  51000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6    Ahmed Khan  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     USA     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  31.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#Handle Duplicates 
df.duplicated() #checks if there is a duplicate entry or not
df[["country","gender"]].duplicated() #checks duplicates in particular colunms
df2=df.copy()
df2.drop_duplicates()
df2.fillna(0)
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   0.0  Canada   Female  62000.0
# 3    3          Alex   0.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      0.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6             0  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0       0     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   0.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA        0  58000.0

# %%
df.dtypes
df2=df.copy()
df2=df2.fillna(0)
df2["age"]=df2["age"].astype("int64").copy()
df2.dtypes

df["gender"].str.upper()
df["gender"].str.capitalize()
df["name"].str.split()
df["country"].str.contains("india", case=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7       NaN
# 8     False
# 9     False
# 10    False
# Name: country, dtype: object

# %%
aqi_data=pd.read_csv("globalAirQuality.csv")
aqi_data["timestamp"].dtype
aqi_data["timestamp"]=pd.to_datetime(aqi_data["timestamp"])
aqi_data["timestamp"].dtype
# Out:
# dtype('<M8[ns]')

# %%
date_str=pd.Series(["2026-12-31"])
type(date_str.dtype)
# Out:
# numpy.dtypes.ObjectDType

# %%
df2=df.copy()
df2["tax"]=df2["income"].apply(lambda x:"20%" if x>=50000 else "10%")
gender_map={"Male" : "M", "Female" : "F" , "Unknown" : "U"}
df2["gender"]=df2["gender"].map(gender_map)
df2.assign(new_income= df2["income"] * 1.1)
df2["country"]=df2["country"].replace("USA","United States")
df2.rename(columns={"income":"salary"})
df2.sort_values(["income"])
df2["age"]=df2["age"].fillna(50)
df2["income"]=df2["income"].fillna(50)
#sorting
sorted_df=df2.sort_values(["income","age"])
sorted_df.sort_index()
#reset index
sorted_df.reset_index()
sorted_df.reset_index(drop=True)
#ranking
sorted_df["ranking"]=sorted_df["income"].rank()
sorted_df["ranking"]=sorted_df["income"].rank(ascending=True,method="dense")
sorted_df["ranking"]=sorted_df["income"].rank(ascending=True,method="min")
sorted_df["ranking"]=sorted_df["income"].rank(ascending=True,method="max")
#in case of class by default the mean of the ranks are assgned to both rows when method is dense no rank is skipped and whole values are used,in min the lowest rank is assigned to both and in max highest rank is assigned to both 
sorted_df[["id","name","age","country","gender","income","ranking","tax"]]
#sorted_df=sorted_df[["name","age","country","gender","income","tax","ranking","id"]]
sorted_df
# Out:
#     id          name   age        country gender   income  tax  ranking
# 4    4  Maria Garcia  34.0          Spain      F     50.0  10%      1.0
# 9    9   Carlos Ruiz  50.0         Mexico      M  45000.0  10%      2.0
# 3    3          Alex  50.0  United States      U  47000.0  10%      3.0
# 5    5        Li Wei  27.0          China      M  51000.0  20%      4.0
# 0    1      John Doe  29.0  United States      M  55000.0  20%      6.0
# 1    1      John Doe  29.0  United States      M  55000.0  20%      6.0
# 10  10   Emily Davis  31.0  United States    NaN  58000.0  20%      7.0
# 8    8    Rachel Lee  29.0  United States      F  62000.0  20%      9.0
# 2    2    Jane Smith  50.0         Canada      F  62000.0  20%      9.0
# 7    7    Ahmed Khan  38.0            NaN      M  68000.0  20%     10.0
# 6    6           NaN  45.0          India      F  73000.0  20%     11.0

# %%
df2=df.copy()
new_col_order=[col for col in df2.columns if col !="id"] + ["id"]
print(new_col_order)
df2[new_col_order]
# Out:
# ['name', 'age', 'country', 'gender', 'income', 'id']
#             name   age country   gender   income  id
# 0       John Doe  29.0     USA     Male  55000.0   1
# 1       John Doe  29.0     USA     Male  55000.0   1
# 2     Jane Smith   NaN  Canada   Female  62000.0   2
# 3           Alex   NaN     USA  Unknown  47000.0   3
# 4   Maria Garcia  34.0   Spain   Female      NaN   4
# 5         Li Wei  27.0   China     Male  51000.0   5
# 6            NaN  45.0   India   Female  73000.0   6
# 7     Ahmed Khan  38.0     NaN     Male  68000.0   7
# 8     Rachel Lee  29.0     USA   Female  62000.0   8
# 9    Carlos Ruiz   NaN  Mexico     Male  45000.0   9
# 10   Emily Davis  31.0     USA      NaN  58000.0  10

# %%
df2=df.copy()
df2=df2.fillna(0)
df2=df2.drop_duplicates()
df2=df2.sort_values("income")
df2=df2.reset_index(drop=True)
df2.to_csv("sorted_data.csv")

# %%
df2
# Out:
#    id          name   age country   gender   income
# 0   4  Maria Garcia  34.0   Spain   Female      0.0
# 1   9   Carlos Ruiz   0.0  Mexico     Male  45000.0
# 2   3          Alex   0.0     USA  Unknown  47000.0
# 3   5        Li Wei  27.0   China     Male  51000.0
# 4   1      John Doe  29.0     USA     Male  55000.0
# 5  10   Emily Davis  31.0     USA        0  58000.0
# 6   2    Jane Smith   0.0  Canada   Female  62000.0
# 7   8    Rachel Lee  29.0     USA   Female  62000.0
# 8   7    Ahmed Khan  38.0       0     Male  68000.0
# 9   6             0  45.0   India   Female  73000.0

# %%
df.groupby("country")["income"].mean()
df.groupby("country")["income"].min()
df.groupby("country")["income"].max()
df.groupby("gender")["income"].mean()
df.groupby("country")["income"].agg(["mean","max","min"])
df.groupby("country")["income"].agg(avg_sal="mean",max_sal="max",min_sal="min")

df.groupby("country").agg(
    mean_sal=("income","mean"),
    min_age=("age","min")
)
df.groupby("country").agg({
    "income":"mean",
    "age":"min"
})
# Out:
#           income   age
# country
# Canada   62000.0   NaN
# China    51000.0  27.0
# India    73000.0  45.0
# Mexico   45000.0   NaN
# Spain        NaN  34.0
# USA      55400.0  29.0

# %%
df=pd.DataFrame({
    "country":["USA","USA","India","India"],
    "year":[2020,2021,2022,2023],
    "sales":[100,120,90,110],
    "profit":[20,25,18,22],
    #"tax":[10,15,20,25]
})

melted_df=df.melt(
    id_vars=["country","year"],
    value_vars=["sales","profit"],
    var_name="metrics",
    value_name="values"
)

melted_df.pivot(
    index=["country","year"], #we have to pass unique values in index so we are passing two different attributes
    columns="metrics",
    values="values"
)
# Out:
# metrics       profit  sales
# country year
# India   2022      18     90
#         2023      22    110
# USA     2020      20    100
#         2021      25    120

# %%
df
# Out:
#   country  year  sales  profit
# 0     USA  2020    100      20
# 1     USA  2021    120      25
# 2   India  2022     90      18
# 3   India  2023    110      22

# %%
df=pd.read_csv("employee_data.csv")
df["Age"].hist()
df.plot(kind="scatter", x="Age",y="Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
df_customers = pd.DataFrame({
    "customer_id": [1, 2, 3, 4],
    "name": ["Adam", "Bob", "Charlie", "Dave"]
})

df_orders = pd.DataFrame({
    "order_id": [101, 102, 103, 104],
    "customer_id": [2, 1, 4, 5],
    "amount": [250, 120, 300, 180]
})

pd.merge(df_customers,df_orders, on="customer_id") #merged on the common column 
pd.merge(df_customers,df_orders, on="customer_id" , how="left") #merged on the common column and the left table is kept intact and right tables missing values are given Nan
pd.merge(df_customers,df_orders, on="customer_id", how="right") #merged on the common column and the Right tbales values are retained and left is files with Nan
pd.merge(df_customers,df_orders, on="customer_id", how="outer") #merged on the common column and both the tables are kept intact the missing values are fillled with Nan
# Out:
#    customer_id     name  order_id  amount
# 0            1     Adam     102.0   120.0
# 1            2      Bob     101.0   250.0
# 2            3  Charlie       NaN     NaN
# 3            4     Dave     103.0   300.0
# 4            5      NaN     104.0   180.0

# %%
df_customers
# Out:
#    customer_id     name
# 0            1     Adam
# 1            2      Bob
# 2            3  Charlie
# 3            4     Dave

# %%
df_orders
# Out:
#    order_id  customer_id  amount
# 0       101            2     250
# 1       102            1     120
# 2       103            4     300
# 3       104            5     180

# %%
df1 = pd.DataFrame({
    "id": [1, 2, 3],
    "name": ["Adam", "Bob", "Charlie"]
})

df2 = pd.DataFrame({
    "id": [4, 5, 6],
    "name": ["David", "Eva", "Frank"]
})

pd.concat([df1,df2]) #row wise concat
pd.concat([df1,df2], ignore_index=True) #row wise concat dropping the index

pd.concat([df1,df2], axis=1) #column wise concat
# Out:
#    id     name  id   name
# 0   1     Adam   4  David
# 1   2      Bob   5    Eva
# 2   3  Charlie   6  Frank
