# %%
from sklearn import datasets

# %%
df= datasets.load_iris(as_frame=True).frame

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
X=df.drop(columns="target")
y=df["target"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(
    X,y,test_size=0.3,random_state=42,stratify=y
)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
kernels=["linear", "poly", "rbf", "sigmoid"]
c_vals=[1,2,3,4,5]
for kernel in kernels:
    print(f"For Kernel {kernel}")
    for c in c_vals:
        model=SVC(C=c,kernel=kernel)
        model.fit(X_train_scaled,y_train)
        y_pred=model.predict(X_test_scaled)
        print(f"Accuracy for C={c} is :", accuracy_score(y_test,y_pred))
# Out:
# For Kernel linear
# Accuracy for C=1 is : 0.9111111111111111
# Accuracy for C=2 is : 0.9333333333333333
# Accuracy for C=3 is : 0.9333333333333333
# Accuracy for C=4 is : 0.8888888888888888
# Accuracy for C=5 is : 0.8888888888888888
# For Kernel poly
# Accuracy for C=1 is : 0.8666666666666667
# Accuracy for C=2 is : 0.8888888888888888
# Accuracy for C=3 is : 0.8888888888888888
# Accuracy for C=4 is : 0.9111111111111111
# Accuracy for C=5 is : 0.9111111111111111
# For Kernel rbf
# Accuracy for C=1 is : 0.9333333333333333
# Accuracy for C=2 is : 0.9111111111111111
# Accuracy for C=3 is : 0.9111111111111111
# Accuracy for C=4 is : 0.9333333333333333
# Accuracy for C=5 is : 0.9333333333333333
# For Kernel sigmoid
# Accuracy for C=1 is : 0.9111111111111111
# Accuracy for C=2 is : 0.8888888888888888
# Accuracy for C=3 is : 0.8666666666666667
# Accuracy for C=4 is : 0.8666666666666667
# Accuracy for C=5 is : 0.8666666666666667
